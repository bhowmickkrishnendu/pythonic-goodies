# %%
# Concept: if / else
cpu = 85

if cpu > 80:
    print("High CPU usage")
else:
    print("CPU is normal")
# Out:
# High CPU usage

# %%
# Multiple Conditions (elif)
cpu = 65

if cpu > 80:
    print("High")
elif cpu > 50:
    print("Moderate")
else:
    print("Low")
# Out:
# Moderate

# %% [markdown]
# #### Logical Operators
#
# | Operator | Meaning                      |
# | -------- | ---------------------------- |
# | `and`    | both conditions must be true |
# | `or`     | at least one true            |
# | `not`    | reverse condition            |
#
# ```
# cpu = 85
# memory = 70
#
# if cpu > 80 and memory > 60:
#     print("High load on system")
# ```

# %%
# Multiple conditions
cpu = 82
memory = 45

if cpu > 80:
    print("CPU is high")
elif cpu > 50:
    print("CPU is moderate")
else:
    print("CPU is low")

if cpu > 80 and memory < 50:
    print("CPU high but memory OK")
# Out:
# CPU is high
# CPU high but memory OK

# %% [markdown]
# #### NOTEBOOK NOTE — Conditionals
# -----------------------------------
# #### Concept: if / else
# #### What it does: Executes code based on conditions
# ```
# cpu = 75
#
# if cpu > 80:
#     print("High CPU")
# elif cpu > 50:
#     print("Moderate CPU")
# else:
#     print("Low CPU")
# ```
# ##### Logical operators
# ##### and, or, not
#
# ##### Key takeaway: Used for decision making in scripts and automation
# ##### Practice: Create conditions for disk, memory, and CPU alerts
# ##### Time suggestion: 30 min

# %%
cpu = 60

if cpu > 80:
    print("High")
elif cpu > 50:
    print("Medium")
else:
    print("Low")
# Out:
# Medium

# %%
cpu = 71
memory = 71

if cpu > 70 and memory > 70:
    print("Scale up")
else:
    print("No Issue")
# Out:
# Scale up

# %%
if cpu > 80:
    print("High CPU")
