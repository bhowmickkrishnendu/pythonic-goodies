# %% [markdown]
# # Concept: Variables & Data Types
# # What it does: Stores and manages data in Python
#
# # Basic types
# age = 28                    # integer
# price = 99.99               # float
# name = "Krishnendu"         # string
# is_active = True            # boolean
# data = None                 # NoneType
#
# # Type checking
# print(type(age))
#
# # Dynamic typing
# x = 10
# x = "now I'm a string"
#
# # f-string (recommended)
# print(f"Name: {name}, Age: {age}")
#
# # Practice:
# # 1. Create 5 variables of different types
# # 2. Print them using f-strings
# # 3. Change type of one variable and print again
#
# # Time suggestion: 20–30 min hands-on

# %% [markdown]
# 📓 NOTEBOOK NOTE — Type Casting
# -----------------------------------
# # Concept: Type Conversion
# # What it does: Converts one data type into another
#
# x = "100"
# x = int(x)   # string → integer
#
# y = 50
# y = str(y)   # integer → string
#
# # Key takeaway: Data from files/APIs is often string — convert before using
# # Practice: Convert CPU usage from string to float and print
# # Time suggestion: 15–20 min

# %%
name = "Krish"
age = 30
cpu_usage = 65.5
is_server_up = True

print(f"Name: {name}")
print(f"Age: {age}")
print(f"CPU Usage: {cpu_usage}%")
print(f"Server Status: {is_server_up}")

print(type(name))
print(type(age))
print(type(cpu_usage))
print(type(is_server_up))
# Out:
# Name: Krish
# Age: 30
# CPU Usage: 65.5%
# Server Status: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
disk = 80
print(f"Disk usage is {disk}%")
# Out:
# Disk usage is 80%

# %%
x = "100"
x = int(x)
print(type(x))
# Out:
# <class 'int'>

# %%
x = "50"
y = 10
print(x + str(y))
# Out:
# 5010

# %%
cpu = "75.5"
cpu = float(cpu)
print(cpu + 10)
# Out:
# 85.5
